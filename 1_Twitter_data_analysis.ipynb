# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayakrishna12345/Data-Analytics-Lab/blob/master/1_Twitter_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
consumer_key = "foFLVVemhXK717LmF99I18aW3"
consumer_secret = "zx1vvJSmgVnZiuxEEZcRUrBhy5erjU4FRCNyIWgEdPe4FjpgkQ"
access_key = "1028257874181480449-FifuJTS1OZ18T7daOyNQSy6QqhaRtF"
access_secret = "Pv6O5VkE6zwxHd2KHlQIyur4IbFYmUlnTHdJgB3OMXbQ7"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)
query = "#got"

language = "en"

# %%
results = api.search(q=query, lang=language,count=1000)

for tweet in results:
    print (tweet.user.screen_name,"Tweeted:",tweet.text)
# Out:
# AisomwanP Tweeted: RT @bbnaijaupdates: Who rocked it better
# Like for Khaleesi Retweet for Ebuka
# #BBNaija #BBNaija2019 #GOT
# #BBNaijaUpdates #BBNaija2019 #Pe…
# tamaraa994 Tweeted: https://t.co/mHoGLAjOwP
#
# Game of Thrones alternative ending that has more sense than the actual ending!… https://t.co/PvqEWmzNTB
# lesterbagwell Tweeted: I don’t know why but the battle of winterfell still excites me. See how the red witch lighted the swords of the Dothraki 😁 #GoT
# CookieLoverOwO Tweeted: RT @TunaEmpress: My cat does not want Danny on the throne.😂
# #GOT #GameOfThrones https://t.co/815ZuJQa8Q
# horsfall_diana Tweeted: RT @bbnaijaupdates: Who rocked it better
# Like for Khaleesi Retweet for Ebuka
# #BBNaija #BBNaija2019 #GOT
# #BBNaijaUpdates #BBNaija2019 #Pe…
# freefolkbot Tweeted: The Dothraki kind of forgot they died #GoT #GameofThrones https://t.co/NnMEzpuEIA https://t.co/a5P5vVvlMP
# Daraujo_4 Tweeted: The war may have ended but this battle has just begun #GOT
#
# ...

# %%
import csv

csvfile=open('tweets.csv','a')

csvwriter=csv.writer(csvfile)

for tweet in tweepy.Cursor(api.search,
                           q = "#got",
                           since = "2019-04-01",
                           until = "2019-06-01",
                           lang = "en").items():

    csvwriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
    print (tweet.created_at, tweet.text)
csvfile.close()
