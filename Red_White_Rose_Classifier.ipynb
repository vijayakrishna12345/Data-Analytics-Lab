# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayakrishna12345/Data-Analytics-Lab/blob/master/Red_White_Rose_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import cv2
import numpy as np
import os
from google.colab.patches import cv2_imshow

# %%
os.chdir("/gdrive/My Drive")
os.listdir()
# Out:
# ['How to get started with Drive.pdf',
#  'Photo album.gslides',
#  'Google Photos',
#  'Std11-CompSci-EM.pdf',
#  "80's tamil songs",
#  "80's tamil songs ",
#  'Untitled folder',
#  "Can't write this season off.gdoc",
#  'Lesson plan.gdoc',
#  'Untitled0.ipynb',
#  'Untitled document.gdoc',
#  'Rankings.gsheet',
#  'Untitled document (1).gdoc',
#  'Untitled document (2).gdoc',
#  'Untitled document (3).gdoc',
#  'Untitled document (4).gdoc',
#  'Untitled document (5).gdoc',
#  'Essay (1).gdoc',
#  'part 1.gdoc',
#  'Untitled document (13).gdoc',
#  'DLI C-FX-02 Certificate | Deep Learning Institute.pdf',
#  'Untitled document (12).gdoc',
#  'Untitled spreadsheet.gsheet',
#  'Untitled document (11).gdoc',
#  'Colab Notebooks',
#  'Untitled document (10).gdoc',
#  'stop words.txt',
#  'resume.csv',
#  'db.ipynb',
#  'Sample.ipynb',
#  'samp_model.bin',
#  'job_description.csv',
#  'Stop.txt',
#  'Summary.gdoc',
#  'Lesson plan (1).gdoc',
#  'MUKESH_RESUME.pdf',
#  'VK_resume.pdf',
# ...

# %%
red_images = os.listdir("Red")
white_images = os.listdir("White")

# %%
image=cv2.imread("Red/"+red_images[0])
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=601x900 at 0x7F7E1BB509B0>

# %%
img_hsv=cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
cv2_imshow(img_hsv)
# Out:
# <PIL.Image.Image image mode=RGB size=601x900 at 0x7F7E1B2D1CF8>

# %%
lower_red = np.array([0,50,50])
upper_red = np.array([10,255,255])
mask0 = cv2.inRange(img_hsv, lower_red, upper_red)
cv2_imshow(mask0)
# Out:
# <PIL.Image.Image image mode=L size=601x900 at 0x7F7E1B2DF128>

# %%
lower_red = np.array([170,50,50])
upper_red = np.array([180,255,255])
mask1 = cv2.inRange(img_hsv, lower_red, upper_red)
cv2_imshow(mask1)
# Out:
# <PIL.Image.Image image mode=L size=601x900 at 0x7F7E1B2E0160>

# %%
mask = mask0+mask1
cv2_imshow(mask1)
# Out:
# <PIL.Image.Image image mode=L size=601x900 at 0x7F7E1B2D1DD8>

# %%
output_img = image.copy()
output_img[np.where(mask==0)] = 0
cv2_imshow(output_img)
# Out:
# <PIL.Image.Image image mode=RGB size=601x900 at 0x7F7E1B2DF048>

# %%
output_hsv = img_hsv.copy()
output_hsv[np.where(mask==0)] = 0
cv2_imshow(output_hsv)
# Out:
# <PIL.Image.Image image mode=RGB size=601x900 at 0x7F7E1B2DF080>
